# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
country_df = pd.read_csv('country-visas.csv')

# %%
country_df.head()
# Out:
#        country code continent  AFG  ALB  DZA  AND  AGO  ATG  ARG ...   USA  \
# 0  Afghanistan  AFG      Asia  NaN  4.0  4.0  4.0  4.0  3.0  4.0 ...   4.0
# 1      Albania  ALB    Europe  4.0  NaN  4.0  0.0  4.0  0.0  4.0 ...   4.0
# 2      Algeria  DZA    Africa  4.0  4.0  NaN  4.0  4.0  3.0  4.0 ...   4.0
# 3      Andorra  AND    Europe  4.0  0.0  4.0  NaN  4.0  0.0  0.0 ...   0.0
# 4       Angola  AGO    Africa  4.0  4.0  4.0  4.0  NaN  3.0  4.0 ...   4.0
#
#    URY  UZB  VUT  VAT  VEN  VNM  YEM  ZMB  ZWE
# 0  4.0  4.0  4.0  4.0  4.0  4.0  4.0  3.0  3.0
# 1  4.0  4.0  4.0  0.0  4.0  4.0  4.0  1.0  3.0
# 2  4.0  4.0  4.0  4.0  4.0  4.0  1.0  4.0  1.0
# 3  0.0  4.0  0.0  0.0  0.0  4.0  4.0  1.0  1.0
# 4  4.0  4.0  4.0  4.0  4.0  4.0  4.0  1.0  0.0
#
# [5 rows x 197 columns]

# %%
new_columns = list()
for col in country_df.columns:
    if col in country_df['code'].values:
        new_columns.append(country_df[country_df.code == col]['country'].values[0])
    else:
        new_columns.append(col)

# %%
country_df.columns = new_columns

# %%
country_df.fillna(5,inplace=True)

# %%
country_lats = pd.read_csv('worldcities.csv')

# %%
country_lats = country_lats[country_lats.capital == 'primary']

# %%
country_df = country_df.merge(country_lats[['country','lat','lng']],on='country')

# %%
country_df.drop(['code','continent'],inplace=True,axis=1)

# %%
country_df.to_csv('country_preprocessed.csv')

# %%
visa_df = pd.melt(country_df, id_vars=['country'])

# %%
visa_df.columns = ['country1','country2','visa_type']

# %%
visa_df = visa_df.merge(country_lats[['country','lat','lng']],left_on='country2',right_on='country')

# %%
visa_df = visa_df.merge(country_lats[['country','lat','lng']],left_on='country1',right_on='country')

# %%
visa_df.drop(['country_x','country_y'],inplace=True,axis=1)

# %%
visa_df.columns = ['country1','country2','visa_type','lat2','lng2','lat1','lng1']

# %%
visa_df.to_csv('country_preprocessed.csv')

# %%
visa_df.head()
# Out:
#       country1     country2  visa_type     lat2     lng2     lat1     lng1
# 0  Afghanistan  Afghanistan        5.0  34.5167  69.1833  34.5167  69.1833
# 1  Afghanistan      Albania        4.0  41.3275  19.8189  34.5167  69.1833
# 2  Afghanistan      Algeria        4.0  36.7631   3.0506  34.5167  69.1833
# 3  Afghanistan      Andorra        4.0  42.5000   1.5165  34.5167  69.1833
# 4  Afghanistan       Angola        4.0  -8.8383  13.2344  34.5167  69.1833

# %%
df = pd.read_csv('country_preprocessed.csv')

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# country1       object
# country2       object
# visa_type     float64
# lat2          float64
# lng2          float64
# lat1          float64
# lng1          float64
# dtype: object

# %%
or (df['visa_type'] == 3))

# %%
df[df.country1 == 'Japan']
# Out:
#        Unnamed: 0 country1              country2  visa_type     lat2  \
# 13908       13908    Japan           Afghanistan        4.0  34.5167
# 13909       13909    Japan               Albania        0.0  41.3275
# 13910       13910    Japan               Algeria        4.0  36.7631
# 13911       13911    Japan               Andorra        0.0  42.5000
# 13912       13912    Japan                Angola        4.0  -8.8383
# 13913       13913    Japan             Argentina        0.0 -34.6025
# 13914       13914    Japan               Armenia        1.0  40.1812
# 13915       13915    Japan             Australia        2.0 -35.2830
# 13916       13916    Japan               Austria        0.0  48.2000
# 13917       13917    Japan            Azerbaijan        1.0  40.3953
# 13918       13918    Japan               Bahrain        1.0  26.2361
# 13919       13919    Japan            Bangladesh        1.0  23.7231
# 13920       13920    Japan              Barbados        0.0  13.1020
# 13921       13921    Japan               Belarus        0.0  53.9000
# 13922       13922    Japan               Belgium        0.0  50.8333
# 13923       13923    Japan                Belize        0.0  17.2520
# 13924       13924    Japan                 Benin        4.0   6.4833
# 13925       13925    Japan                 Benin        4.0   6.4000
# 13926       13926    Japan                Bhutan        4.0  27.4730
# 13927       13927    Japan               Bolivia        0.0 -16.4980
# 13928       13928    Japan               Bolivia        0.0 -19.0410
# 13929       13929    Japan              Botswana        0.0 -24.6463
# 13930       13930    Japan                Brazil        4.0 -15.7833
# 13931       13931    Japan                Brunei        0.0   4.8833
# 13932       13932    Japan              Bulgaria        0.0  42.6833
# 13933       13933    Japan          Burkina Faso        4.0  12.3703
# 13934       13934    Japan               Burundi        4.0  -3.3761
# 13935       13935    Japan              Cambodia        1.0  11.5500
# 13936       13936    Japan              Cameroon        4.0   3.8667
# 13937       13937    Japan                Canada        0.0  45.4167
# ...           ...      ...                   ...        ...      ...
# 14061       14061    Japan              Suriname        0.0   5.8350
# 14062       14062    Japan             Swaziland        0.0 -26.3167
# 14063       14063    Japan             Swaziland        0.0 -26.4667
# 14064       14064    Japan                Sweden        0.0  59.3508
# 14065       14065    Japan           Switzerland        0.0  46.9167
# 14066       14066    Japan                 Syria        4.0  33.5000
# 14067       14067    Japan            Tajikistan        1.0  38.5600
# 14068       14068    Japan              Tanzania        1.0  -6.1833
# 14069       14069    Japan              Tanzania        1.0  -6.8000
# 14070       14070    Japan              Thailand        0.0  13.7500
# 14071       14071    Japan           Timor-Leste        1.0  -8.5594
# 14072       14072    Japan                  Togo        1.0   6.1319
# 14073       14073    Japan                 Tonga        1.0 -21.1385
# 14074       14074    Japan               Tunisia        0.0  36.8028
# 14075       14075    Japan                Turkey        0.0  39.9272
# 14076       14076    Japan          Turkmenistan        4.0  37.9500
# 14077       14077    Japan                Tuvalu        1.0  -8.5167
# 14078       14078    Japan                Uganda        1.0   0.3167
# 14079       14079    Japan               Ukraine        0.0  50.4334
# 14080       14080    Japan  United Arab Emirates        1.0  24.4667
# 14081       14081    Japan        United Kingdom        0.0  51.5000
# 14082       14082    Japan         United States        2.0  38.9047
# 14083       14083    Japan               Uruguay        0.0 -34.8580
# 14084       14084    Japan            Uzbekistan        4.0  41.3117
# 14085       14085    Japan               Vanuatu        0.0 -17.7334
# 14086       14086    Japan             Venezuela        0.0  10.5010
# 14087       14087    Japan               Vietnam        0.0  21.0333
# 14088       14088    Japan                 Yemen        4.0  15.3547
# 14089       14089    Japan                Zambia        1.0 -15.4166
# 14090       14090    Japan              Zimbabwe        1.0 -17.8178
#
#            lng2    lat1      lng1
# 13908   69.1833  35.685  139.7514
# 13909   19.8189  35.685  139.7514
# 13910    3.0506  35.685  139.7514
# 13911    1.5165  35.685  139.7514
# 13912   13.2344  35.685  139.7514
# 13913  -58.3975  35.685  139.7514
# 13914   44.5136  35.685  139.7514
# 13915  149.1290  35.685  139.7514
# 13916   16.3666  35.685  139.7514
# 13917   49.8622  35.685  139.7514
# 13918   50.5831  35.685  139.7514
# 13919   90.4086  35.685  139.7514
# 13920  -59.6165  35.685  139.7514
# 13921   27.5666  35.685  139.7514
# 13922    4.3333  35.685  139.7514
# 13923  -88.7671  35.685  139.7514
# 13924    2.6166  35.685  139.7514
# 13925    2.5200  35.685  139.7514
# 13926   89.6390  35.685  139.7514
# 13927  -68.1500  35.685  139.7514
# 13928  -65.2595  35.685  139.7514
# 13929   25.9119  35.685  139.7514
# 13930  -47.9161  35.685  139.7514
# 13931  114.9333  35.685  139.7514
# 13932   23.3167  35.685  139.7514
# 13933   -1.5247  35.685  139.7514
# 13934   29.3600  35.685  139.7514
# 13935  104.9166  35.685  139.7514
# 13936   11.5167  35.685  139.7514
# 13937  -75.7000  35.685  139.7514
# ...         ...     ...       ...
# 14061  -55.1670  35.685  139.7514
# 14062   31.1333  35.685  139.7514
# 14063   31.2000  35.685  139.7514
# 14064   18.0973  35.685  139.7514
# 14065    7.4670  35.685  139.7514
# 14066   36.3000  35.685  139.7514
# 14067   68.7739  35.685  139.7514
# 14068   35.7500  35.685  139.7514
# 14069   39.2683  35.685  139.7514
# 14070  100.5166  35.685  139.7514
# 14071  125.5795  35.685  139.7514
# 14072    1.2228  35.685  139.7514
# 14073 -175.2206  35.685  139.7514
# 14074   10.1797  35.685  139.7514
# 14075   32.8644  35.685  139.7514
# 14076   58.3833  35.685  139.7514
# 14077  179.2166  35.685  139.7514
# 14078   32.5833  35.685  139.7514
# 14079   30.5166  35.685  139.7514
# 14080   54.3666  35.685  139.7514
# 14081   -0.1167  35.685  139.7514
# 14082  -77.0163  35.685  139.7514
# 14083  -56.1711  35.685  139.7514
# 14084   69.2949  35.685  139.7514
# 14085  168.3166  35.685  139.7514
# 14086  -66.9170  35.685  139.7514
# 14087  105.8500  35.685  139.7514
# 14088   44.2066  35.685  139.7514
# 14089   28.2833  35.685  139.7514
# 14090   31.0447  35.685  139.7514
#
# [183 rows x 8 columns]

# %%
import requests
import json

result_df = pd.DataFrame()

year_list = [str(x) for x in range(2006,2020)]
for year in year_list:
    url = 'https://www.henleypassportindex.com/fetch?url=rankings%2F' + year
    response = requests.get(url)
    df_rank = pd.read_json(response.content.decode('utf-8'))
    df_rank['country_name'] = df_rank['passport'].apply(lambda x:x['name'])
    result_df = pd.concat([result_df,df_rank],ignore_index=True)

# %%
result_df.drop('passport',inplace=True,axis=1)

# %%
result_df.to_csv('country_rank_score.csv',index=False)

# %%
income_data = pd.read_json("D:\\DataViz\\Project\\visa-free-travel\\cleandata.json")

# %%
income_data.to_csv('IncomingGDPData.csv',index=False)

# %%
result_df = pd.read_csv('country_rank_score.csv')

# %%
income_data.head()
# Out:
#                                          connections country_name  \
# 0  [Sri Lanka, Malaysia, Algeria, Dominica, Ecuad...        Yemen
# 1  [Barbados, Peru, Bahamas, Hong Kong, Ireland, ...         Fiji
# 2  [Barbados, Canada, Dominica, United Kingdom, P...       Brunei
# 3  [Peru, Panama, Argentina, Bahamas, Ireland, Ke...      Bolivia
# 4  [Kenya, Kuwait, Venezuela, Malaysia, Egypt, In...     Cambodia
#
#    gdp_percapita  incoming  iso3_digit_code        lat        long  outgoing
# 0        1473.10    990000              887  15.552727   48.516388         0
# 1        7750.43    658000              242 -16.578193  179.414413         0
# 2       71776.65    225000               96   4.535277  114.727669         0
# 3        6131.06    798000               68 -16.290154  -63.588653    837000
# 4        1006.84   2882000              116  12.565679  104.990963    710000

# %%
scatter_countries = pd.merge(result_df[['score','rank','year','country_name']],income_data[['country_name','gdp_percapita','incoming','outgoing']],on='country_name',how='left')

# %%
years = scatter_countries.year.unique().tolist()
k = 0
fig , ax = plt.subplots(7,2, sharex=True, sharey=True, figsize=(6,6))
for i in range(0,7):
    for j in range(0,2):
        ax[i][j].plot(scatter_countries[scatter_countries.year==years[k]]['rank'],scatter_countries[scatter_countries.year==years[k]].gdp_percapita,'o')
        k += 1

# %%
# Out:
# 14

# %%
for yr in list(scatter_countries.year.unique()):
    plt.plot(scatter_countries[scatter_countries.year==yr]['rank'],scatter_countries[scatter_countries.year==yr].gdp_percapita,'o')
    plt.show()

# %%
scatter_countries['rank']import pickle

# open a file, where you stored the pickled data
file = open('important', 'rb')

# dump information to that file
data = pickle.load(file)

# close the file
file.close()
# Out:
# 0         1
# 1         1
# 2         1
# 3         2
# 4         2
# 5         2
# 6         3
# 7         3
# 8         3
# 9         3
# 10        3
# 11        4
# 12        4
# 13        4
# 14        4
# 15        5
# 16        6
# 17        6
# 18        6
# 19        7
# 20        8
# 21        9
# 22        9
# 23        9
# 24        9
# 25       10
# 26       11
# 27       11
# 28       12
# 29       13
#        ...
# 2722     92
# 2723     92
# 2724     92
# 2725     92
# 2726     93
# 2727     93
# 2728     94
# 2729     95
# 2730     95
# 2731     95
# 2732     96
# 2733     97
# 2734     97
# 2735     97
# 2736     98
# 2737     99
# 2738     99
# 2739     99
# 2740    100
# 2741    100
# 2742    101
# 2743    102
# 2744    102
# 2745    102
# 2746    103
# 2747    104
# 2748    104
# 2749    105
# 2750    106
# 2751    107
# Name: rank, Length: 2752, dtype: int64

# %%
import pickle
import pandas as pd

# open a file, where you stored the pickled data
file = open("D:\\DataViz\\Project\\df.pickle", 'rb')

# dump information to that file
data = pickle.load(file)

# close the file
file.close()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-c261573a9784> in <module>()
#       6
#       7 # dump information to that file
# ----> 8 data = pickle.load(file)
#       9
#      10 # close the file
#
# ImportError: No module named 'pandas.core.internals.managers'; 'pandas.core.internals' is not a package
